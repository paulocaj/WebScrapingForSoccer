# %% [markdown]
# <a href="https://colab.research.google.com/github/paulocaj/WebScrapingForSoccer/blob/main/Jogos_WebScrapping.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
from google.colab import files

# %%
response = requests.get('https://fbref.com/en/squads/b8fd03ef/2022-2023/Manchester-City-Stats')


html_pagina = BeautifulSoup(response.content, 'html.parser')
html_tabela = html_pagina.find('table', attrs={'id': 'matchlogs_for'})


tbody_html = html_tabela.find('tbody')
data_html = html_tabela.findAll('tr')
# print(tbody_html.prettify())
data_list = []
for tr in data_html:
    rows = []
    for data in tr.findAll(['th','td']):
        rows.append(data.text)
    data_list.append(rows)
# print(data_list)
matches_df = pd.DataFrame(data_list)
matches_df.columns = matches_df.iloc[0]
matches_df = matches_df[1:]
matches_df.drop('Match Report',axis= 1, inplace= True)
matches_df.drop('Notes', axis=1, inplace=True)
matches_df.drop('Round', axis=1, inplace=True)
matches_df.drop('Comp', axis=1, inplace=True)
print(matches_df)
matches_df.to_excel('City.xlsx', index=False)
# Out:
# 0         Date    Time  Day    Venue Result GF GA        Opponent   xG  xGA  \
# 1   2022-07-30  17:00   Sat  Neutral      L  1  3       Liverpool
# 2   2022-08-07  16:30   Sun     Away      W  2  0        West Ham  2.2  0.5
# 3   2022-08-13  15:00   Sat     Home      W  4  0     Bournemouth  1.7  0.1
# 4   2022-08-21  16:30   Sun     Away      D  3  3   Newcastle Utd  2.1  1.8
# 5   2022-08-27  15:00   Sat     Home      W  4  2  Crystal Palace  2.2  0.1
# ..         ...     ...  ...      ...    ... .. ..             ...  ...  ...
# 57  2023-05-21  16:00   Sun     Home      W  1  0         Chelsea  1.2  1.2
# 58  2023-05-24  20:00   Wed     Away      D  1  1        Brighton  1.8  2.2
# 59  2023-05-28  16:30   Sun     Away      L  0  1       Brentford  1.6  1.3
# 60  2023-06-03  15:00   Sat  Neutral      W  2  1  Manchester Utd
# 61  2023-06-10  22:00   Sat  Neutral      W  1  0        it Inter  1.0  1.7
#
# 0  Poss Attendance          Captain Formation           Referee
# 1    57                  Rúben Dias     4-3-3      Craig Pawson
# 2    75     62,443   İlkay Gündoğan     4-3-3    Michael Oliver
# 3    67     53,453   İlkay Gündoğan   4-2-3-1       David Coote
# 4    69     52,258   İlkay Gündoğan     4-3-3    Jarred Gillett
# 5    74     53,112  Kevin De Bruyne   4-2-3-1    Darren England
# ..  ...        ...              ...       ...               ...
# 57   64     53,490      Kyle Walker    3-4-3◆    Michael Oliver
# 58   60     31,388   İlkay Gündoğan     4-3-3      Simon Hooper
# 59   65     17,120      Kyle Walker   3-2-4-1       John Brooks
# 60   60     83,179   İlkay Gündoğan   3-2-4-1      Paul Tierney
# 61   55     71,412   İlkay Gündoğan   3-2-4-1  Szymon Marciniak
#
# [61 rows x 15 columns]

# %%
files.download('City.xlsx')

# %%
df = pd.read_excel('City.xlsx')
df
# Out:
#           Date    Time  Day    Venue Result  GF  GA        Opponent   xG  xGA  \
# 0   2022-07-30  17:00   Sat  Neutral      L   1   3       Liverpool  NaN  NaN
# 1   2022-08-07  16:30   Sun     Away      W   2   0        West Ham  2.2  0.5
# 2   2022-08-13  15:00   Sat     Home      W   4   0     Bournemouth  1.7  0.1
# 3   2022-08-21  16:30   Sun     Away      D   3   3   Newcastle Utd  2.1  1.8
# 4   2022-08-27  15:00   Sat     Home      W   4   2  Crystal Palace  2.2  0.1
# ..         ...     ...  ...      ...    ...  ..  ..             ...  ...  ...
# 56  2023-05-21  16:00   Sun     Home      W   1   0         Chelsea  1.2  1.2
# 57  2023-05-24  20:00   Wed     Away      D   1   1        Brighton  1.8  2.2
# 58  2023-05-28  16:30   Sun     Away      L   0   1       Brentford  1.6  1.3
# 59  2023-06-03  15:00   Sat  Neutral      W   2   1  Manchester Utd  NaN  NaN
# 60  2023-06-10  22:00   Sat  Neutral      W   1   0        it Inter  1.0  1.7
#
#     Poss Attendance          Captain Formation           Referee
# 0     57        NaN       Rúben Dias     4-3-3      Craig Pawson
# 1     75     62,443   İlkay Gündoğan     4-3-3    Michael Oliver
# 2     67     53,453   İlkay Gündoğan   4-2-3-1       David Coote
# 3     69     52,258   İlkay Gündoğan     4-3-3    Jarred Gillett
# 4     74     53,112  Kevin De Bruyne   4-2-3-1    Darren England
# ..   ...        ...              ...       ...               ...
# 56    64     53,490      Kyle Walker    3-4-3◆    Michael Oliver
# 57    60     31,388   İlkay Gündoğan     4-3-3      Simon Hooper
# 58    65     17,120      Kyle Walker   3-2-4-1       John Brooks
# 59    60     83,179   İlkay Gündoğan   3-2-4-1      Paul Tierney
# 60    55     71,412   İlkay Gündoğan   3-2-4-1  Szymon Marciniak
#
# [61 rows x 15 columns]
